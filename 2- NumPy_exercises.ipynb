# %% [markdown]
# ## NumPy Practice Notebook – Part 2
# ### This notebook focuses on practicing core NumPy operations through hands-on examples.

# %% [markdown]
# Import numpy as np and see the version.

# %% [markdown]
# How to create a 1D array?

# %% [markdown]
# How to create a boolean array?

# %% [markdown]
# How to extract all odd numbers from 1D array?

# %% [markdown]
# How to replace all odd numbers from 1D array with -1 without changing arr?

# %% [markdown]
# How to reshape a 1D array to 2D array with 2 row?

# %% [markdown]
# How to stack two arrays vertically?

# %% [markdown]
# How to generate custom sequences in numpy without hardcoding?

# %% [markdown]
# How to get the common items between two python numpy arrays?

# %% [markdown]
# How to remove from one array those items that exist in another?

# %% [markdown]
# How to get the positions where elements of two arrays match?

# %% [markdown]
# Get all items between 5 and 10 from a.

# %% [markdown]
# How to make a python function that handles scalars to work on numpy arrays?

# %% [markdown]
# How to reverse the rows of a 2D array?

# %% [markdown]
# How to create a 2D array of shape 5x3 containing random floats between 5 and 10?

# %% [markdown]
# How to compute the mean, median, standard deviation of a numpy array?

# %% [markdown]
# How to convert an array of arrays into a flat 1d array?
