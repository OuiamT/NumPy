# %% [markdown]
# ## Welcome to this **first NumPy exercise book**.
# ### I designed this book to practice NumPy and enhance understanding through a series of practical exercises.

# %% [markdown]
# 1. Import NumPy with an alias

# %% [markdown]
# 2. Print the numpy version.

# %% [markdown]
# 3. Create a numpy array of size 10, filled with zeros.

# %% [markdown]
# 4. Create a numpy array with values ranging from 10 to 49.

# %% [markdown]
# 5. Create a numpy matrix of 2*2 integers, filled with ones.

# %% [markdown]
# 6. Create a numpy matrix of 3*2 float numbers, filled with ones.

# %% [markdown]
# 7. Given the X numpy array, create a new numpy array with the same shape and type as X, filled with ones.

# %% [markdown]
# 8. Given the X numpy matrix, create a new numpy matrix with the same shape and type as X, filled with zeros.

# %% [markdown]
# 9. Create a numpy matrix of 4*4 integers, filled with fives.

# %% [markdown]
# 10. Create a 3*3 identity numpy matrix with ones on the diagonal and zeros elsewhere.

# %% [markdown]
# 11. Create a numpy array, filled with 3 random integer values between 0 and 10.

# %% [markdown]
# 12. Create a 3* 3*3 numpy matrix, filled with random float values.

# %% [markdown]
# 13. Given the X python list convert it to an Y numpy array.

# %% [markdown]
# 14. Create a numpy array with the odd numbers between 1 to 10.

# %% [markdown]
# 15. Create a numpy array with numbers from 1 to 10, in descending order.

# %% [markdown]
# 16. Create a 3*3 numpy matrix, filled with values ranging from 0 to 8.

# %% [markdown]
# 17. Show the memory size of the given Z numpy matrix.

# %% [markdown]
# 18. Given the X numpy array, show it's first and last  element.

# %% [markdown]
# 19. Given the X numpy array, show it's first three elements.

# %% [markdown]
# 20. Given the X numpy array, show all middle elements.

# %% [markdown]
# 21. Given the X numpy array, show the elements in an odd position.

# %% [markdown]
# 22. Given the X numpy matrix, show the first row elements.

# %% [markdown]
# 23. Given the X numpy matrix, show the last row elements.

# %% [markdown]
# 24. Given the X numpy matrix, show the first element on first row.

# %% [markdown]
# 25. Given the X numpy matrix, show the first element on last row.

# %% [markdown]
# 26. Given the X numpy matrix, show the last two elements on the first two rows.

# %% [markdown]
# 27. Order (sort) the given numpy array.

# %% [markdown]
# 28. Given the X numpy array, change the 50 with a 40.

# %% [markdown]
# 29. Given the X numpy matrix, change the last row with all 1.

# %% [markdown]
# 30. Given the X numpy matrix, add 5 to every element.

# %% [markdown]
# 31. Given the y numpy array, make a mask showing negative elements.

# %% [markdown]
# 32. Given the y numpy array, get numbers higher than 5.

# %% [markdown]
# 33. Given the y numpy array, get numbers higher than the elements mean.

# %% [markdown]
# 34. Given the z numpy array, show the sum of its elements.

# %% [markdown]
# 35. Given the z numpy array, show the mean value of its elements.

# %% [markdown]
# 36. Given the X numpy matrix, show the sum of its columns.

# %% [markdown]
# 37. Given the X numpy matrix, show the mean value of its rows.

# %% [markdown]
# 38. Given the X numpy array, show the max value of its elements.

# %% [markdown]
# 39. Given the X numpy array, show the min value of its elements.
